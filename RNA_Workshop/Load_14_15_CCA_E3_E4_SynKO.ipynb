# %% [markdown]
# <a href="https://colab.research.google.com/github/dtabuena/Workshop/blob/main/RNA_Workshop/Load_14_15_CCA_E3_E4_SynKO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scanpy --quiet
# !pip install pybiomart --quiet
# !pip install python-igraph --quiet
# !pip install louvain --quiet
# !pip install pynndescent --quiet

# %%
import scanpy as sc
import os
import pandas as pd

# %%
os.chdir("C:/Users/dennis.tabuena/Dropbox (Gladstone)/0_Projects/Seurat_Scanpy/10X_data")

file = "./obj_apoeSyn/"
adata = sc.read_10x_mtx(file)

# %%
medadata = pd.read_csv('./metadata.csv')
display(medadata)
# Out:
#        Unnamed: 0  \
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ...           ...
# 30037       30038
# 30038       30039
# 30039       30040
# 30040       30041
# 30041       30042
#
#       c..ki_AAACCTGAGAATGTTG.1....ki_AAAGCAACAGCTGTAT.1....ki_AAAGTAGTCTTTAGGG.1...  \
# 0                                  ki_AAACCTGAGAATGTTG-1
# 1                                  ki_AAAGCAACAGCTGTAT-1
# 2                                  ki_AAAGTAGTCTTTAGGG-1
# 3                                  ki_AACACGTCAATGGTCT-1
# 4                                  ki_AACCATGAGGTAGCCA-1
# ...                                                  ...
# 30037                             syn_TGCCCTAGTATGCTTG-7
# 30038                             syn_TGGTTCCAGATAGGAG-7
# 30039                             syn_TTAGGACGTCCTCTTG-7
# 30040                             syn_TTCGGTCTCATGTCCC-7
# 30041                             syn_TTGTAGGTCGTTGACA-7
#
# ...

# %%
medadata2 = pd.read_csv('./metadata2.csv')
display(medadata2)
# Out:
#                    Unnamed: 0  nGene  nUMI  \
# 0       ki_AAACCTGAGAATGTTG-1   1969  3663
# 1       ki_AAAGCAACAGCTGTAT-1   1810  3556
# 2       ki_AAAGTAGTCTTTAGGG-1   1660  3778
# 3       ki_AACACGTCAATGGTCT-1   1547  3068
# 4       ki_AACCATGAGGTAGCCA-1   1026  1885
# ...                       ...    ...   ...
# 30037  syn_TGCCCTAGTATGCTTG-7    740  1280
# 30038  syn_TGGTTCCAGATAGGAG-7   1450  2751
# 30039  syn_TTAGGACGTCCTCTTG-7    432   731
# 30040  syn_TTCGGTCTCATGTCCC-7    769  1437
# 30041  syn_TTGTAGGTCGTTGACA-7    820  1467
#
#                                       orig.ident  percent.mito  res.0.6  \
# 0      E3vE4_SeuratObject_allMouseGenes_20180819      0.000273        2
# 1      E3vE4_SeuratObject_allMouseGenes_20180819      0.000281        2
# 2      E3vE4_SeuratObject_allMouseGenes_20180819      0.001853        2
# 3      E3vE4_SeuratObject_allMouseGenes_20180819      0.001630        2
# 4      E3vE4_SeuratObject_allMouseGenes_20180819      0.000000        2
# ...

# %%
#


# keys = [k for k in adata.obs.index]
# keys = [k.split("_")[0]+"_"+k.split("-")[-1] for k in keys]
# unique_keys = sorted(list(set(keys)))
# print(unique_keys)
# Out:
# ['ki_1', 'ki_15', 'ki_16', 'ki_17', 'ki_18', 'ki_31', 'ki_32', 'ki_4', 'syn_1', 'syn_3', 'syn_5', 'syn_7']
